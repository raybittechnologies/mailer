# %%
import re
import os
from typing import List, Optional

from langchain.callbacks import get_openai_callback
from langchain_openai import ChatOpenAI

from kor.extraction import create_extraction_chain
from langchain_community.document_loaders import TextLoader

from pydantic import BaseModel, Field, validator
from kor import extract_from_documents, from_pydantic, create_extraction_chain

from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo-0125",
    temperature=0,
)

# %%
class Person(BaseModel):
    name: Optional[str] = Field(
        description="The Person First Name which is hidden inside the email address."
    )
    email: Optional[str] = Field(
        description="The email address."
    )
schema, extraction_validator = from_pydantic(
    Person,
    description="""You're an information extractor working for a data analytics firm.
    Your primary responsibility is to process unstructured data and extract valuable information
    for various clients across industries. Recently, your team received a dataset containing a list
    of email addresses from a client who wants to identify person associated with these emails. The person first name is hidden inside the email address think step by step.
    Your task is to accurately extract the first name of the person from the email addresses
    and present the findings in a structured format for further analysis. Your expertise in natural language
    processing and data extraction techniques will be crucial in completing this task effectively. Do not consider 'info' as a person first name.""",

    examples = [
    (
        'kimrobinson@bestdayeverpicnics.com',
        {"name": 'Kim', 'email': 'kimrobinson@bestdayeverpicnics.com'}
    ),
    (
        'krista@ohwhatfunpartyco.com',
        {"name": 'Krista', 'email': 'krista@ohwhatfunpartyco.com'}
    ),
    (
        'levenuebrandon@gmail.com',
        {"name": 'Brandon', 'email': 'levenuebrandon@gmail.com'}
    ),
    (
        'lorrin@wagnerevents.com',
        {"name": 'Lorrin', 'email': 'lorrin@wagnerevents.com'}
    ),
    (
        'michelle@preciousmomentseventsllc.com',
        {"name": 'Michelle', 'email': 'michelle@preciousmomentseventsllc.com'}
    ),
    (
        'myevent.kingdomkatering@gmail.com',
        {"name": 'Kingdom', 'email': 'myevent.kingdomkatering@gmail.com'}
    ),
    (
        'mylezedwardcreations@gmail.com',
        {"name": 'Mylez Edward', 'email': 'mylezedwardcreations@gmail.com'}
    ),
    (
        'nancycottoevents@gmail.com',
        {"name": 'Nancy', 'email': 'nancycottoevents@gmail.com'}
    ),
    (
        'natalia@daysrememberedbynd.com',
        {"name": 'Natalia', 'email': 'natalia@daysrememberedbynd.com'}
    ),
    (
        'nikkiplansparties@gmail.com',
        {"name": 'Nikki', 'email': 'nikkiplansparties@gmail.com'}
    ),
    (
        'nomadicfeteart@gmail.com',
        {"name": 'Nomadic', 'email': 'nomadicfeteart@gmail.com'}
    ),
    (
        'pam@igniteyouroccasion.com',
        {"name": 'Pam', 'email': 'pam@igniteyouroccasion.com'}
    ),
    (
        'pamela@atmospheresdesigns.com',
        {"name": 'Pamela', 'email': 'pamela@atmospheresdesigns.com'}
    ),
    (
        'john@atmospheresdesigns.com',
        {"name": 'John', 'email': 'john@atmospheresdesigns.com'}
    ),
    (
        'gue@atmospheresdesigns.com',
        {"name": 'Gue', 'email': 'gue@atmospheresdesigns.com'}
    ),
    (
        'renee@partyhosthelper.com',
        {"name": 'Renee', 'email': 'renee@partyhosthelper.com'}
    ),
    (
        'sherrywilliamsmusic@verizon.net',
        {"name": 'Sherry', 'email': 'sherrywilliamsmusic@verizon.net'}
    ),
    (
        'Britt@elcidsunset.com',
        {"name": 'Britt', 'email': 'Britt@elcidsunset.com'}
    ),
    (
        'acesbargrill@gmail.com',
        {"name": 'None', 'email': 'acesbargrill@gmail.com'}
    ),
    (
        'adgreservation@alilahotels.com',
        {"name": 'None', 'email': 'adgreservation@alilahotels.com'}
    ),
    (
        'adr@coi.cz',
        {"name": 'None', 'email': 'adr@coi.cz'}
    ),
    (
        'advancedbookingtennis@outlook.com',
        {"name": 'None', 'email': 'advancedbookingtennis@outlook.com'}
    ),
],
    many=True,
)

# %%
chain = create_extraction_chain(
    
    llm,
    schema,
    encoder_or_encoder_class="csv",
    validator=extraction_validator,
    input_formatter="triple_quotes",
)

# %% [markdown]
# **Paste The List of Emails**

# %%
emails = ['gm@lecolonialsf.com', 'diningroommanager@lecolonialsf.com', 'specialevents@lecolonialsf.com', 'info@lecolonialsf.com', 'booking@924gilman.org', 'community@924gilman.org', 'booking@924gilman.org', 'ameliewinebar@hotmail.com', 'info@arcanasf.com', 'info@arcanasf.com', 'info@ticketweb.com', 'boxoffice@augusthallsf.com', 'auracinemasf@gmail.com', 'reservations@plumpjack.com', 'balboa@plumpjack.com', 'booking@baltickiss.com', 'kabukifrontdesk@jdvhotels.com', 'kabukifrontdesk@jdvhotels.com', 'bryang@bartza.com', 'aghanadan@gmail.com', 'rebecca@provocateur-media.com', 'rena@provocateur-media.com', 'reservations@barbarossalounge.com', 'info@barbarossalounge.com', 'danchanpresents@gmail.com', 'info@beauxsf.com', 'events@beauxsf.com', 'bottles@beauxsf.com', 'bottles@beauxsf.com', 'thebellecora@gmail.com', 'info@bks-sf.com', 'info@biscuitsandblues.com', 'info@biscuitsandblues.com', 'contact@sansoxygen.com', 'blondiesbarsf@gmail.com', 'events@bodegasf.com', 'paria@bodegasf.com', 'music@boomboomroom.com', 'zander@boomboomroom.com', 'email@bottomofthehill.com', 'host@bourbonandbranch.com', 'kelli@brickandmortarmusic.org', 'info@brickandmortarmusic.org', 'booking@brickandmortarmusic.org', 'info@ticketweb.com', 'info@brickandmortarmusic.org', 'info@ticketweb.com', 'emeuse1@yahoo.com', 'cafevankleefinfo@gmail.com', 'gillian@casementsbar.com', 'volunteers@catscornersf.com', 'info@catscornersf.com', 'info@chambers-sf.com', 'info@chambers-sf.com', 'info@cttcomedy.com', 'tickets@cttcomedy.com', 'groups@clubfugazisf.com', 'info@clubfugazisf.com', 'kevin@prismaticcommunications.com', 'info@cb-pr.com', 'info@clubfugazisf.com', 'clubwaziemasf@gmail.com', 'post@comstocksaloon.com', 'press@absinthegroup.com', 'post@comstocksaloon.com', 'thecraft@dahliasf.com', 'info@
com', 'patronservices@sfsymphony.org', 'mvannorman@sfsymphony.org', 'leilani@southsidesf.com', 'info@goodbeer.com', 'info@swmh.com', 'info@swigbar.com', 'taintedlovesanfrancisco@gmail.com', 'daniel@swanentertainment.com', 'tonypours@gmail.com', 'theshowdownsf@gmail.com', 'sfo1hsf.concierge@1hotels.com', 'sfo1hsf-terrene@1hotels.com', 'sfo1hsf-terrene@1hotels.com', 'alembic@booksmith.com', 'thealleypianobar@gmail.com', 'thealleypianobar@gmail.com', 'sam@backroommusic.com', 'sam@backroommusic.com', 'leemarieparmelee@hotmail.com', 'lisa@lisanourse.com', 'info@thebeehivesf.com', 'thebitterendsf@gmail.com', 'blarneystonebar@gmail.com', 'thebuenavista@comcast.net', 'info@thechapelsf.com', 'info@thechapelsf.com', 'info@thedevilsacre.com', 'info@thedevilsacre.com', 'specialevents@livenation.com', 'thefillmore@livenation.com', 'sf.events@livenation.com', 'events@flytrapsf.com', 'valen@flytrapsf.com', 'info@ticketweb.com', 'info@ticketweb.com', 'hello@thelaundromatsf.com', 'booking@thelostchurch.org', 'ticketing@thelostchurch.org', 'hq@thelostchurch.org', 'info@thepagebar.com', 'info@patiosf.com', 'info@thepatiosf.com', 'damien@thepawnshopsf.com', 'damien@thepawnshopsf.com', 'info@redpoppyarthouse.org', 'volunteer@redpoppyarthouse.org', 'booking@riptidesf.com', 'riptidesf@gmail.com', 'will@theroyalesf.com', 'westontoyou@gmail.com', 'westontoyou@gmail.com', 'info@therumpusroomsf.com', 'info@theseastarsf.com', 'info@sherwoodsf.com', 'info@sherwoodsf.com', 'soundroomoakland@gmail.com', 'soundroomoakland@gmail.com', 'boxoffice@thespeakeasysf.com', 'boxoffice@thespeakeasysf.com', 'swerney@thetreasurysf.com', 'lisa@lisanourse.com', 'hil@thetreasurysf.com', 'arnold@thetreasurysf.com', 'contact@thetreasurysf.com', 'alexeyberlind@gmail.com', 'info@thevalenciaroom.com', 'proteam@mopro.com', 'noreply@mopro.com', 'declan@valleytavern.us', 'viewlounge@marriott.com', 'booking@theeparkside.com', 'theeparkside@gmail.com', 'info@thirdrailbarsf.com', 'thrills@thrillersocialclub.com', 'tongaroom@fairmont.com', 'sanfrancisco@fairmont.com', 'topesf@gmail.com', 'info@tropisueno.com', 'tupelosf@gmail.com', 'frank@funnyfrank.com', 'info@uccellolounge.com', 'vicswinehouse@gmail.com', 'info@violets-sf.com', 'host@bourbonandbranch.com', 'lindsay@yielddogpatch.com', 'lindsay@yielddogpatch.com']
emails = ['Museperformancebooking@gmail.com', 'info@analoguenyc.com', 'info@dazzlejazz.com', 'contact@canaryclubnyc.com', 'press@canaryclubnyc.com', 'reservations@canaryclubnyc.com']

# %%
def create_chunks(path=None, emails=None):
    if path:
        loader = TextLoader(path)
        data = loader.load()
        data[0].page_content = data[0].page_content.replace('\n', ', ')
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
        docs = text_splitter.split_documents(data)
    elif emails:
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
        if isinstance(emails, str):
            emails = [emails]
        emails = ', '.join(emails)
        texts = text_splitter.create_documents([emails])
        docs = text_splitter.split_documents(texts)
    else:
        raise ValueError("You must provide either a file path or a list of emails.")
    return docs
split_docs = create_chunks(emails=emails)
split_docs
# Out:
# [Document(page_content='Museperformancebooking@gmail.com, info@analoguenyc.com, info@dazzlejazz.com, contact@canaryclubnyc.com, press@canaryclubnyc.com, reservations@canaryclubnyc.com')]

# %%
with get_openai_callback() as cb:
    document_extraction_results = await extract_from_documents(
        chain, split_docs, max_concurrency=3, use_uid=False, return_exceptions=True
    )
    print    (f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Successful Requests: {cb.successful_requests}")
    print(f"Total Cost (USD): ${cb.total_cost}")
# Out:
# Total Tokens: 1188
# Prompt Tokens: 1123
# Completion Tokens: 65
# Successful Requests: 1
# Total Cost (USD): $0.0006590000000000001

# %%
def generate_email_name_pairs(json_data):
    email_name_pairs = []
    for record in json_data:
        employee_list = record.get('data', {}).get('person', [])
        for employee in employee_list:
            email = employee.get('email', '')
            name = employee.get('name', '')  # Extracting the first name
            email_name_pairs.append({'Email': email, 'First_Name': name})
    return email_name_pairs

generate_email_name_pairs(document_extraction_results)
# Out:
# [{'Email': 'Museperformancebooking@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@analoguenyc.com', 'First_Name': 'None'},
#  {'Email': 'info@dazzlejazz.com', 'First_Name': 'None'},
#  {'Email': 'contact@canaryclubnyc.com', 'First_Name': 'None'},
#  {'Email': 'press@canaryclubnyc.com', 'First_Name': 'None'},
#  {'Email': 'reservations@canaryclubnyc.com', 'First_Name': 'None'}]

# %%
async def extract_first_names_from_emails(path=None, emails=None):
    split_docs = create_chunks(emails=emails)

    with get_openai_callback() as cb:
        document_extraction_results = await extract_from_documents(
            chain, split_docs, max_concurrency=3, use_uid=False, return_exceptions=True
        )
        print    (f"Total Tokens: {cb.total_tokens}")
        print(f"Prompt Tokens: {cb.prompt_tokens}")
        print(f"Completion Tokens: {cb.completion_tokens}")
        print(f"Successful Requests: {cb.successful_requests}")
        print(f"Total Cost (USD): ${cb.total_cost}")

    return document_extraction_results

# %%
document_extraction_results = await extract_first_names_from_emails(emails=emails)
generate_email_name_pairs(document_extraction_results)
# Out:
# Total Tokens: 1188
# Prompt Tokens: 1123
# Completion Tokens: 65
# Successful Requests: 1
# Total Cost (USD): $0.0006590000000000001
# [{'Email': 'Museperformancebooking@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@analoguenyc.com', 'First_Name': 'None'},
#  {'Email': 'info@dazzlejazz.com', 'First_Name': 'None'},
#  {'Email': 'contact@canaryclubnyc.com', 'First_Name': 'None'},
#  {'Email': 'press@canaryclubnyc.com', 'First_Name': 'None'},
#  {'Email': 'reservations@canaryclubnyc.com', 'First_Name': 'None'}]
