# %%
import os
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_openai import ChatOpenAI

# %%
# API Key
os.environ["OPENAI_API_KEY"] = "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"

# %%
# GPT 3.5 Model
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo-0125",
    temperature=0,
)

# %%
def extract_first_name(email):
    '''
    Use the LLM to extract the first name from the given email.
    '''
    template = """Extract the first names from the given list of email addresses. The email address is: {email}.
                  Do not add any attributes, Do NOT add any additional words. 
                  Just First Name of Person only. If there is no first name of person then return 'None'."""
    
    prompt = PromptTemplate(template=template, input_variables=["email"])

    llm_chain = LLMChain(prompt=prompt, llm=llm)
    output = llm_chain.invoke(input=email)
    return output['text']

# %%
email = 'catering@lbyc.org'
first_name = extract_first_name(email)
first_name
# Out:
# 'None'

# %%
import sqlite3

connect = sqlite3.connect('apps/db.sqlite3')
cursor = connect.cursor()

cursor.execute("SELECT * FROM uploadedservice")

emails = cursor.fetchall()

# %%
for email in emails[:100]:
    email = email[5]
    possible_first_names = extract_first_name(email)
    print("Possible first name(s) in", email, ":", possible_first_names)
# Out:
# Possible first name(s) in reservations@lasalabythesea.com : None
# Possible first name(s) in info@lasalabythesea.com : None
# Possible first name(s) in info@moshfunkitchen.com : None
# Possible first name(s) in hello@naopoolclub.com : None
# Possible first name(s) in legal@nikkibeach.com : None
# Possible first name(s) in businessdevelopment@nikkibeach.com : None
# Possible first name(s) in press@nikkibeach.com : None
# Possible first name(s) in hola@waikikitarifa.com : None
# Possible first name(s) in 2145pizza@gmail.com : None
# Possible first name(s) in 2ndpchsocial@gmail.com : None
# Possible first name(s) in 3408@verdugobar.com : None
# Possible first name(s) in 4thstreetgaragetemecula@gmail.com : None
# Possible first name(s) in Aaron@steadybrewing.com : Aaron
# Possible first name(s) in abegail@ajc-pr.com : Abegail
# Possible first name(s) in hello@theia-la.com : None
# Possible first name(s) in accessibility@dylish.com : None
# Possible first name(s) in accessibility@joeyrestaurants.com : None
# Possible first name(s) in acesbargrill@gmail.com : None
# Possible first name(s) in adgreservation@alilahotels.com : None
# Possible first name(s) in adr@coi.cz : None
# Possible first name(s) in advancedbookingtennis@outlook.com : None
# Possible first name(s) in ahoy@lonelyoyster.com : None
# Possible first name(s) in Allyson@blindbarber.com : Allyson
# Possible first name(s) in aloha@royalhawaiianlb.com : None
# Possible first name(s) in amendoza@vistavalley.com : Amanda
# Possible first name(s) in annacpeko@gmail.com : Anna
# Possible first name(s) in artifex@artifexbrewing.com : None
# Possible first name(s) in ask@thecellarsite.com : None
# Possible first name(s) in astansbery@watergrill.com : None
# Possible first name(s) in atriumpark.homestay@gmail.com : None
# Possible first name(s) in awensman@shadycanyongolfclub.com : None
# Possible first name(s) in ayresmanhattanbeach@ayreshotels.com : None
# Possible first name(s) in bacarisilverlake@bacari.us : None
# Possible first name(s) in bacowineandgrill@gmail.com : None
# Possible first name(s) in bands@danapointstillwater.com : None
# Possible first name(s) in barinfo@gold-diggers.com : None
# Possible first name(s) in basano@thecrosbyclub.com : Basano
# Possible first name(s) in bccsupport@brentwoodcc.net : None
# Possible first name(s) in bcook@balboabayclub.com : Brenda
# Possible first name(s) in bd.nolita@thebutchersdaughter.com : None
# Possible first name(s) in bd.west@thebutchersdaughter.com : None
# Possible first name(s) in beautyandessexlainfo@taogroup.com : None
# Possible first name(s) in ben@lawlessbeer.com : Ben
# Possible first name(s) in info@lawlessbeer.com : None
# Possible first name(s) in billyr@infinityresidential.com : Billy
# Possible first name(s) in BlackKnightGastroLounge@gmail.com : None
# Possible first name(s) in bluedaisycafe@gmail.com : None
# Possible first name(s) in boatcomusic@gmail.com : None
# Possible first name(s) in bocaraton@luxetm.com : None
# Possible first name(s) in bookcbh@houseofan.com : None
# Possible first name(s) in booking@alvas.com : None
# Possible first name(s) in booking@mozambiqueoc.com : None
# Possible first name(s) in booking@rentelectricboats.com : None
# Possible first name(s) in bookings@verandasbeachhousemb.com : None
# Possible first name(s) in bottleinnriviera@gmail.com : None
# Possible first name(s) in brad@deepmix.com : Brad
# Possible first name(s) in briodanapoint@gmail.com : None
# Possible first name(s) in Brogers@lacasadelcamino.com : Brogers
# Possible first name(s) in follow up sept : None
# Possible first name(s) in brokenshaker.miami@thefreehand.com : None
# Possible first name(s) in brooksbar.rvsd@gmail.com : Brooks
# Possible first name(s) in browley@pacificpalmsresort.com : None
# Possible first name(s) in Bryan.Piersidesc@gmail.com : Bryan
# Possible first name(s) in Fri/sat : None
# Possible first name(s) in bullardg@sbcglobal.net : None
# Possible first name(s) in burbank@granvillecafe.com : None
# Possible first name(s) in weho@granvillecafe.com : None
# Possible first name(s) in cantinacompadres@gmail.com : None
# Possible first name(s) in Captureone@aol.com : None
# Possible first name(s) in casadelpescador20@gmail.com : None
# Possible first name(s) in casafinarestaurant@gmail.com : None
# Possible first name(s) in casino@commercecasino.net : None
# Possible first name(s) in Castawayburbank@srcmail.com : None
# Possible first name(s) in castlecreekpr@gmail.com : None
# Possible first name(s) in catandfiddlerestaurant@gmail.com : None
# Possible first name(s) in caterdeli@gmail.com : None
# Possible first name(s) in cantersdeli@gmail.com : None
# Possible first name(s) in catering@homerestaurantla.com : None
# Possible first name(s) in catering@lbyc.org : None
# Possible first name(s) in chad25Degrees@gmail.com : Chad
# Possible first name(s) in chapel@southbayweddingcenter.com : None
# Possible first name(s) in chorne@mcbridals.com : None
# Possible first name(s) in chris@winegallerylaguna.com : Chris
# Possible first name(s) in christinm@orangecountyminingco.com : Christin
# Possible first name(s) in christopher.heuisler@marriott.com : Christopher
# Possible first name(s) in ClubManager@hhyc.org : None
# Possible first name(s) in cocktails@librarybarla.com : None
# Possible first name(s) in compassballoons@gmail.com : None
# Possible first name(s) in concierge@midwaycarrental.com : None
# Possible first name(s) in concierge@verse.la : None
# Possible first name(s) in reservations@verse.la : None
# Possible first name(s) in confirmation@angelesnational.com : None
# Possible first name(s) in contact@barshalife.com : None
# Possible first name(s) in contact@kingsrowpub.com : None
# Possible first name(s) in contact@sansoxygen.com : None
# Possible first name(s) in posse.bar12@gmail.com : None
# Possible first name(s) in contact@urbankitchengroup.com : None
# Possible first name(s) in tiffany@urbankitchengroup.com : Tiffany
# Possible first name(s) in contact@zetanemesis.com : None
# Possible first name(s) in contactus@alisogolf.com : None

# %%
cursor.close()
connect.close()
