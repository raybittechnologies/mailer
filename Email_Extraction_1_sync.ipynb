# %%
import re
import os
import pandas as pd
from tqdm import tqdm
from typing import List, Optional
from langchain.callbacks import get_openai_callback
from langchain_openai import ChatOpenAI

from kor.extraction import create_extraction_chain
from langchain_community.document_loaders import TextLoader

from pydantic import BaseModel, Field, validator
from kor import extract_from_documents, from_pydantic, create_extraction_chain

from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo-0125",
    temperature=0,
)

# %%
class Person(BaseModel):
    name: Optional[str] = Field(
        description="The Person First Name which is hidden inside the email address."
    )
    email: Optional[str] = Field(
        description="The email address."
    )
schema, extraction_validator = from_pydantic(
    Person,
    description="""You're an information extractor working for a data analytics firm.
    Your primary responsibility is to process unstructured data and extract valuable information
    for various clients across industries. Recently, your team received a dataset containing a list
    of email addresses from a client who wants to identify person associated with these emails. The person first name is hidden inside the email address.
    Your task is to accurately extract the first name of the person from the email addresses
    and present the findings in a structured format for further analysis. Your expertise in natural language
    processing and data extraction techniques will be crucial in completing this task effectively. Do not consider 'info' as a person first name. Some of the examples are given belwo:""",

    examples = [
    (
        'kimrobinson@bestdayeverpicnics.com',
        {"name": 'Kim', 'email': 'kimrobinson@bestdayeverpicnics.com'}
    ),
    (
        'krista@ohwhatfunpartyco.com',
        {"name": 'Krista', 'email': 'krista@ohwhatfunpartyco.com'}
    ),
    (
        'levenuebrandon@gmail.com',
        {"name": 'Brandon', 'email': 'levenuebrandon@gmail.com'}
    ),
    (
        'lorrin@wagnerevents.com',
        {"name": 'Lorrin', 'email': 'lorrin@wagnerevents.com'}
    ),
    (
        'michelle@preciousmomentseventsllc.com',
        {"name": 'Michelle', 'email': 'michelle@preciousmomentseventsllc.com'}
    ),
    (
        'myevent.kingdomkatering@gmail.com',
        {"name": 'Kingdom', 'email': 'myevent.kingdomkatering@gmail.com'}
    ),
    (
        'mylezedwardcreations@gmail.com',
        {"name": 'Mylez Edward', 'email': 'mylezedwardcreations@gmail.com'}
    ),
    (
        'nancycottoevents@gmail.com',
        {"name": 'Nancy', 'email': 'nancycottoevents@gmail.com'}
    ),
    (
        'natalia@daysrememberedbynd.com',
        {"name": 'Natalia', 'email': 'natalia@daysrememberedbynd.com'}
    ),
    (
        'nikkiplansparties@gmail.com',
        {"name": 'Nikki', 'email': 'nikkiplansparties@gmail.com'}
    ),
    (
        'nomadicfeteart@gmail.com',
        {"name": 'Nomadic', 'email': 'nomadicfeteart@gmail.com'}
    ),
    (
        'pam@igniteyouroccasion.com',
        {"name": 'Pam', 'email': 'pam@igniteyouroccasion.com'}
    ),
    (
        'pamela@atmospheresdesigns.com',
        {"name": 'Pamela', 'email': 'pamela@atmospheresdesigns.com'}
    ),
    (
        'john@atmospheresdesigns.com',
        {"name": 'John', 'email': 'john@atmospheresdesigns.com'}
    ),
    (
        'gue@atmospheresdesigns.com',
        {"name": 'Gue', 'email': 'gue@atmospheresdesigns.com'}
    ),
    (
        'renee@partyhosthelper.com',
        {"name": 'Renee', 'email': 'renee@partyhosthelper.com'}
    ),
    (
        'sherrywilliamsmusic@verizon.net',
        {"name": 'Sherry', 'email': 'sherrywilliamsmusic@verizon.net'}
    ),
    (
        'Britt@elcidsunset.com',
        {"name": 'Britt', 'email': 'Britt@elcidsunset.com'}
    ),
    (
        'acesbargrill@gmail.com',
        {"name": 'None', 'email': 'acesbargrill@gmail.com'}
    ),
    (
        'adgreservation@alilahotels.com',
        {"name": 'None', 'email': 'adgreservation@alilahotels.com'}
    ),
    (
        'adr@coi.cz',
        {"name": 'None', 'email': 'adr@coi.cz'}
    ),
    (
        'advancedbookingtennis@outlook.com',
        {"name": 'None', 'email': 'advancedbookingtennis@outlook.com'}
    ),
],
    many=True,
)

# %%
chain = create_extraction_chain(
    
    llm,
    schema,
    encoder_or_encoder_class="csv",
    validator=extraction_validator,
    input_formatter="triple_quotes",
)

# %% [markdown]
# **Paste The List of Emails**

# %%
emails = ['gm@lecolonialsf.com', 'diningroommanager@lecolonialsf.com', 'specialevents@lecolonialsf.com', 'info@lecolonialsf.com', 'booking@924gilman.org', 'community@924gilman.org', 'booking@924gilman.org', 'ameliewinebar@hotmail.com', 'info@arcanasf.com', 'info@arcanasf.com', 'info@ticketweb.com', 'boxoffice@augusthallsf.com', 'auracinemasf@gmail.com', 'reservations@plumpjack.com', 'balboa@plumpjack.com', 'booking@baltickiss.com', 'kabukifrontdesk@jdvhotels.com', 'kabukifrontdesk@jdvhotels.com', 'bryang@bartza.com', 'aghanadan@gmail.com', 'rebecca@provocateur-media.com', 'rena@provocateur-media.com', 'reservations@barbarossalounge.com', 'info@barbarossalounge.com', 'danchanpresents@gmail.com', 'info@beauxsf.com', 'events@beauxsf.com', 'bottles@beauxsf.com', 'bottles@beauxsf.com', 'thebellecora@gmail.com', 'info@bks-sf.com', 'info@biscuitsandblues.com', 'info@biscuitsandblues.com', 'contact@sansoxygen.com', 'blondiesbarsf@gmail.com', 'events@bodegasf.com', 'paria@bodegasf.com', 'music@boomboomroom.com', 'zander@boomboomroom.com', 'email@bottomofthehill.com', 'host@bourbonandbranch.com', 'kelli@brickandmortarmusic.org', 'info@brickandmortarmusic.org', 'booking@brickandmortarmusic.org', 'info@ticketweb.com', 'info@brickandmortarmusic.org', 'info@ticketweb.com', 'emeuse1@yahoo.com', 'cafevankleefinfo@gmail.com', 'gillian@casementsbar.com', 'volunteers@catscornersf.com', 'info@catscornersf.com', 'info@chambers-sf.com', 'info@chambers-sf.com', 'info@cttcomedy.com', 'tickets@cttcomedy.com', 'groups@clubfugazisf.com', 'info@clubfugazisf.com', 'kevin@prismaticcommunications.com', 'info@cb-pr.com', 'info@clubfugazisf.com', 'clubwaziemasf@gmail.com', 'post@comstocksaloon.com', 'press@absinthegroup.com', 'post@comstocksaloon.com', 'thecraft@dahliasf.com', 'info@dalvasf.com', 'events@dalvasf.com', 'info@dawnclub.com', 'info@decodancesf.com', 'info@decodancesf.com', 'info@districtsf.com', 'driftwoodbar.sf@gmail.com', 'driftwoodbar.sf@gmail.com', 'johnnyfoleys@live.com', 'festie1@aol.com', 'johnnyfoleys@live.com', 'hello@elriosf.com', 'elriosflive@gmail.com', 'hello@elriosf.com', 'elboroomoakland@gmail.com', 'elboroomoakland@gmail.com', 'info@one65sf.com', 'info@elixirsf.com', 'info@elixirsf.com', 'info@emporiumsf.com', 'sf@emporiumarcadebar.com', 'info@etceterawinebar.com', 'info@etceterawinebar.com', 'dortega@hotelnikkosf.com', 'info@thefiresidelounge.com', 'ts@atownagency.com', 'info@thefiresidelounge.com', 'info@forbiddenislandalameda.com', 'janine@foreigncinema.com', 'info@foreigncinema.com', 'info@foreigncinema.com', 'info@grayarea.org', 'info@gamh.com', 'info@harperandrye.com', 'charlotte@hawthornsf.com', 'info@hawthornsf.com', 'reservations@hawthornsf.com', 'hilo.sf@gmail.com', 'hilo.sf@gmail.com', 'info@hulahoopssf.com', 'info@ironhorsesf.com', 'info@ironhorsesf.com', 'info@ivyroom.com', 'info@ivyroom.com', 'currents@sausalito.gov', 'info@jazzmafia.com', 'info@keysjazzbistro.com', 'info@kilowattbar.com', 'kilowatt@kilowattbar.com', 'info@kilowattbar.com', 'hello@lastritesbar.com', 'lppsf75@gmail.com', 'info@lighthouse-restaurants.com', 'aloha@lycsf.com', 'info@nightbirdrestaurant.com', 'info@lionsdenbarandlounge.com', 'host@localeditionsf.com', 'host@localeditionsf.com', 'lostcatbar@gmail.com', 'lostcatbar@gmail.com', 'tonypours@gmail.com', 'louies.sf@gmail.com', 'info@lushloungesf.com', 'info@madarae.com', 'info@michaelkrouse.com', 'events@mersea.restaurant', 'events@mersea.restaurant', 'info@monarchsf.com', 'jazz@mrtipplessf.com', 'natomacabana@gmail.com', 'info@ticketweb.com', 'booking@neckofthewoodssf.com', 'info@nicksrestaurant.net', 'nicksrockaway@yahoo.com', 'info@novelasf.com', 'viceroy@thedooronline.com', 'development@viceroyhotelgroup.com', 'matt@pixelspread.com', 'impallari@gmail.com', 'hello@rfuenzalida.com', 'info@divinosausalito.com', 'hello@outerlandssf.com', 'hello@outerlandssf.com', 'info@paganidol.com', 'info@paganidol.com', 'info@persona-sf.com', 'events@pier23cafe.com', 'mac@pier23cafe.com', 'info@pier23cafe.com', 'office@pressclubsf.com', 'inquiries@radiogatsy.com', 'noam@radiogatsby.com', 'info@ravenbarsf.com', 'email@redwoodroom.com', 'cliftsocial@sonesta.com', 'info@rickhousebar.com', 'info@rickhousebar.com', 'info@rickshawstop.com', 'info@ryeontheroad.com', 'cablecarlounge@yahoo.com', 'seafood@scomas.com', 'seafood@scomas.com', 'tim@scopodivino.com', 'info@scopodivino.com', 'info@sfjazz.org', 'info@smugglerscovesf.com', 'losttikiisland@yahoo.com', 'soolbar@soolsf.com', 'patronservices@sfsymphony.org', 'mvannorman@sfsymphony.org', 'leilani@southsidesf.com', 'info@goodbeer.com', 'info@swmh.com', 'info@swigbar.com', 'taintedlovesanfrancisco@gmail.com', 'daniel@swanentertainment.com', 'tonypours@gmail.com', 'theshowdownsf@gmail.com', 'sfo1hsf.concierge@1hotels.com', 'sfo1hsf-terrene@1hotels.com', 'sfo1hsf-terrene@1hotels.com', 'alembic@booksmith.com', 'thealleypianobar@gmail.com', 'thealleypianobar@gmail.com', 'sam@backroommusic.com', 'sam@backroommusic.com', 'leemarieparmelee@hotmail.com', 'lisa@lisanourse.com', 'info@thebeehivesf.com', 'thebitterendsf@gmail.com', 'blarneystonebar@gmail.com', 'thebuenavista@comcast.net', 'info@thechapelsf.com', 'info@thechapelsf.com', 'info@thedevilsacre.com', 'info@thedevilsacre.com', 'specialevents@livenation.com', 'thefillmore@livenation.com', 'sf.events@livenation.com', 'events@flytrapsf.com', 'valen@flytrapsf.com', 'info@ticketweb.com', 'info@ticketweb.com', 'hello@thelaundromatsf.com', 'booking@thelostchurch.org', 'ticketing@thelostchurch.org', 'hq@thelostchurch.org', 'info@thepagebar.com', 'info@patiosf.com', 'info@thepatiosf.com', 'damien@thepawnshopsf.com', 'damien@thepawnshopsf.com', 'info@redpoppyarthouse.org', 'volunteer@redpoppyarthouse.org', 'booking@riptidesf.com', 'riptidesf@gmail.com', 'will@theroyalesf.com', 'westontoyou@gmail.com', 'westontoyou@gmail.com', 'info@therumpusroomsf.com', 'info@theseastarsf.com', 'info@sherwoodsf.com', 'info@sherwoodsf.com', 'soundroomoakland@gmail.com', 'soundroomoakland@gmail.com', 'boxoffice@thespeakeasysf.com', 'boxoffice@thespeakeasysf.com', 'swerney@thetreasurysf.com', 'lisa@lisanourse.com', 'hil@thetreasurysf.com', 'arnold@thetreasurysf.com', 'contact@thetreasurysf.com', 'alexeyberlind@gmail.com', 'info@thevalenciaroom.com', 'proteam@mopro.com', 'noreply@mopro.com', 'declan@valleytavern.us', 'viewlounge@marriott.com', 'booking@theeparkside.com', 'theeparkside@gmail.com', 'info@thirdrailbarsf.com', 'thrills@thrillersocialclub.com', 'tongaroom@fairmont.com', 'sanfrancisco@fairmont.com', 'topesf@gmail.com', 'info@tropisueno.com', 'tupelosf@gmail.com', 'frank@funnyfrank.com', 'info@uccellolounge.com', 'vicswinehouse@gmail.com', 'info@violets-sf.com', 'host@bourbonandbranch.com', 'lindsay@yielddogpatch.com', 'lindsay@yielddogpatch.com']

# %%
def create_chunks(path=None, emails=None):
    if path:
        loader = TextLoader(path)
        data = loader.load()
        data[0].page_content = data[0].page_content.replace('\n', ', ')
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
        docs = text_splitter.split_documents(data)
    elif emails:
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
        if isinstance(emails, str):
            emails = [emails]
        emails = ', '.join(emails)
        texts = text_splitter.create_documents([emails])
        docs = text_splitter.split_documents(texts)
    else:
        raise ValueError("You must provide either a file path or a list of emails.")
    return docs
split_docs = create_chunks(emails=emails)

# %%
def generate_email_name_pairs(emails):
    
    split_docs = create_chunks(emails=emails)
    records = []
    with get_openai_callback() as cb:
        for doc in split_docs:
            records.append(chain.invoke(doc.page_content))
        print    (f"Total Tokens: {cb.total_tokens}")
        print(f"Prompt Tokens: {cb.prompt_tokens}")
        print(f"Completion Tokens: {cb.completion_tokens}")
        print(f"Successful Requests: {cb.successful_requests}")
        print(f"Total Cost (USD): ${cb.total_cost}")
        
    email_name_pairs = []
    for record in records:
        employee_list = record['text'].get('data', {}).get('person', [])
        for employee in employee_list:
            email = employee.get('email', '')
            name = employee.get('name', '')  # Extracting the first name
            email_name_pairs.append({'Email': email, 'First_Name': name})
    return email_name_pairs
print(len(emails))
generate_email_name_pairs(emails)
# Out:
# 260
# Total Tokens: 14446
# Prompt Tokens: 11192
# Completion Tokens: 3254
# Successful Requests: 8
# Total Cost (USD): $0.010476999999999998
# [{'Email': 'gm@lecolonialsf.com', 'First_Name': 'None'},
#  {'Email': 'diningroommanager@lecolonialsf.com', 'First_Name': 'None'},
#  {'Email': 'specialevents@lecolonialsf.com', 'First_Name': 'None'},
#  {'Email': 'info@lecolonialsf.com', 'First_Name': 'None'},
#  {'Email': 'booking@924gilman.org', 'First_Name': 'None'},
#  {'Email': 'community@924gilman.org', 'First_Name': 'None'},
#  {'Email': 'booking@924gilman.org', 'First_Name': 'None'},
#  {'Email': 'ameliewinebar@hotmail.com', 'First_Name': 'None'},
#  {'Email': 'info@arcanasf.com', 'First_Name': 'None'},
#  {'Email': 'info@arcanasf.com', 'First_Name': 'None'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'boxoffice@augusthallsf.com', 'First_Name': 'None'},
#  {'Email': 'auracinemasf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'reservations@plumpjack.com', 'First_Name': 'None'},
#  {'Email': 'balboa@plumpjack.com', 'First_Name': 'None'},
#  {'Email': 'booking@baltickiss.com', 'First_Name': 'None'},
#  {'Email': 'kabukifrontdesk@jdvhotels.com', 'First_Name': 'None'},
#  {'Email': 'kabukifrontdesk@jdvhotels.com', 'First_Name': 'None'},
#  {'Email': 'bryang@bartza.com', 'First_Name': 'None'},
#  {'Email': 'aghanadan@gmail.com', 'First_Name': 'None'},
#  {'Email': 'rebecca@provocateur-media.com', 'First_Name': 'None'},
#  {'Email': 'rena@provocateur-media.com', 'First_Name': 'None'},
#  {'Email': 'reservations@barbarossalounge.com', 'First_Name': 'None'},
#  {'Email': 'info@barbarossalounge.com', 'First_Name': 'None'},
#  {'Email': 'danchanpresents@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@beauxsf.com', 'First_Name': 'None'},
#  {'Email': 'events@beauxsf.com', 'First_Name': 'None'},
#  {'Email': 'bottles@beauxsf.com', 'First_Name': 'None'},
#  {'Email': 'bottles@beauxsf.com', 'First_Name': 'None'},
#  {'Email': 'thebellecora@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@bks-sf.com', 'First_Name': 'None'},
#  {'Email': 'info@biscuitsandblues.com', 'First_Name': 'None'},
#  {'Email': 'info@biscuitsandblues.com', 'First_Name': 'None'},
#  {'Email': 'contact@sansoxygen.com', 'First_Name': 'None'},
#  {'Email': 'blondiesbarsf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'events@bodegasf.com', 'First_Name': 'None'},
#  {'Email': 'paria@bodegasf.com', 'First_Name': 'None'},
#  {'Email': 'music@boomboomroom.com', 'First_Name': 'None'},
#  {'Email': 'zander@boomboomroom.com', 'First_Name': 'None'},
#  {'Email': 'email@bottomofthehill.com', 'First_Name': 'None'},
#  {'Email': 'info@biscuitsandblues.com', 'First_Name': 'None'},
#  {'Email': 'contact@sansoxygen.com', 'First_Name': 'None'},
#  {'Email': 'blondiesbarsf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'events@bodegasf.com', 'First_Name': 'None'},
#  {'Email': 'paria@bodegasf.com', 'First_Name': 'Paria'},
#  {'Email': 'music@boomboomroom.com', 'First_Name': 'None'},
#  {'Email': 'zander@boomboomroom.com', 'First_Name': 'Zander'},
#  {'Email': 'email@bottomofthehill.com', 'First_Name': 'None'},
#  {'Email': 'host@bourbonandbranch.com', 'First_Name': 'None'},
#  {'Email': 'kelli@brickandmortarmusic.org', 'First_Name': 'Kelli'},
#  {'Email': 'info@brickandmortarmusic.org', 'First_Name': 'None'},
#  {'Email': 'booking@brickandmortarmusic.org', 'First_Name': 'None'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'info@brickandmortarmusic.org', 'First_Name': 'None'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'emeuse1@yahoo.com', 'First_Name': 'None'},
#  {'Email': 'cafevankleefinfo@gmail.com', 'First_Name': 'None'},
#  {'Email': 'gillian@casementsbar.com', 'First_Name': 'Gillian'},
#  {'Email': 'volunteers@catscornersf.com', 'First_Name': 'None'},
#  {'Email': 'info@catscornersf.com', 'First_Name': 'None'},
#  {'Email': 'info@chambers-sf.com', 'First_Name': 'None'},
#  {'Email': 'info@chambers-sf.com', 'First_Name': 'None'},
#  {'Email': 'info@cttcomedy.com', 'First_Name': 'None'},
#  {'Email': 'tickets@cttcomedy.com', 'First_Name': 'None'},
#  {'Email': 'groups@clubfugazisf.com', 'First_Name': 'None'},
#  {'Email': 'info@clubfugazisf.com', 'First_Name': 'None'},
#  {'Email': 'kevin@prismaticcommunications.com', 'First_Name': 'Kevin'},
#  {'Email': 'info@cb-pr.com', 'First_Name': 'None'},
#  {'Email': 'info@clubfugazisf.com', 'First_Name': 'None'},
#  {'Email': 'clubwaziemasf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'post@comstocksaloon.com', 'First_Name': 'None'},
#  {'Email': 'press@absinthegroup.com', 'First_Name': 'None'},
#  {'Email': 'post@comstocksaloon.com', 'First_Name': 'None'},
#  {'Email': 'thecraft@dahliasf.com', 'First_Name': 'None'},
#  {'Email': 'info@dalvasf.com', 'First_Name': 'None'},
#  {'Email': 'events@dalvasf.com', 'First_Name': 'None'},
#  {'Email': 'info@dawnclub.com', 'First_Name': 'None'},
#  {'Email': 'info@decodancesf.com', 'First_Name': 'None'},
#  {'Email': 'info@decodancesf.com', 'First_Name': 'None'},
#  {'Email': 'info@districtsf.com', 'First_Name': 'None'},
#  {'Email': 'driftwoodbar.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'post@comstocksaloon.com', 'First_Name': 'None'},
#  {'Email': 'thecraft@dahliasf.com', 'First_Name': 'None'},
#  {'Email': 'info@dalvasf.com', 'First_Name': 'None'},
#  {'Email': 'events@dalvasf.com', 'First_Name': 'None'},
#  {'Email': 'info@dawnclub.com', 'First_Name': 'None'},
#  {'Email': 'info@decodancesf.com', 'First_Name': 'None'},
#  {'Email': 'info@decodancesf.com', 'First_Name': 'None'},
#  {'Email': 'info@districtsf.com', 'First_Name': 'None'},
#  {'Email': 'driftwoodbar.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'driftwoodbar.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'johnnyfoleys@live.com', 'First_Name': 'None'},
#  {'Email': 'festie1@aol.com', 'First_Name': 'None'},
#  {'Email': 'johnnyfoleys@live.com', 'First_Name': 'None'},
#  {'Email': 'hello@elriosf.com', 'First_Name': 'None'},
#  {'Email': 'elriosflive@gmail.com', 'First_Name': 'None'},
#  {'Email': 'hello@elriosf.com', 'First_Name': 'None'},
#  {'Email': 'elboroomoakland@gmail.com', 'First_Name': 'None'},
#  {'Email': 'elboroomoakland@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@one65sf.com', 'First_Name': 'None'},
#  {'Email': 'info@elixirsf.com', 'First_Name': 'None'},
#  {'Email': 'info@elixirsf.com', 'First_Name': 'None'},
#  {'Email': 'info@emporiumsf.com', 'First_Name': 'None'},
#  {'Email': 'sf@emporiumarcadebar.com', 'First_Name': 'None'},
#  {'Email': 'info@etceterawinebar.com', 'First_Name': 'None'},
#  {'Email': 'info@etceterawinebar.com', 'First_Name': 'None'},
#  {'Email': 'dortega@hotelnikkosf.com', 'First_Name': 'None'},
#  {'Email': 'info@thefiresidelounge.com', 'First_Name': 'None'},
#  {'Email': 'ts@atownagency.com', 'First_Name': 'None'},
#  {'Email': 'info@thefiresidelounge.com', 'First_Name': 'None'},
#  {'Email': 'info@forbiddenislandalameda.com', 'First_Name': 'None'},
#  {'Email': 'janine@foreigncinema.com', 'First_Name': 'None'},
#  {'Email': 'info@foreigncinema.com', 'First_Name': 'None'},
#  {'Email': 'info@foreigncinema.com', 'First_Name': 'None'},
#  {'Email': 'info@grayarea.org', 'First_Name': 'None'},
#  {'Email': 'info@gamh.com', 'First_Name': 'None'},
#  {'Email': 'info@harperandrye.com', 'First_Name': 'None'},
#  {'Email': 'charlotte@hawthornsf.com', 'First_Name': 'None'},
#  {'Email': 'info@hawthornsf.com', 'First_Name': 'None'},
#  {'Email': 'reservations@hawthornsf.com', 'First_Name': 'None'},
#  {'Email': 'hilo.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'hilo.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@hulahoopssf.com', 'First_Name': 'None'},
#  {'Email': 'info@ironhorsesf.com', 'First_Name': 'None'},
#  {'Email': 'info@gamh.com', 'First_Name': 'None'},
#  {'Email': 'info@harperandrye.com', 'First_Name': 'None'},
#  {'Email': 'charlotte@hawthornsf.com', 'First_Name': 'Charlotte'},
#  {'Email': 'info@hawthornsf.com', 'First_Name': 'None'},
#  {'Email': 'reservations@hawthornsf.com', 'First_Name': 'None'},
#  {'Email': 'hilo.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'hilo.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@hulahoopssf.com', 'First_Name': 'None'},
#  {'Email': 'info@ironhorsesf.com', 'First_Name': 'None'},
#  {'Email': 'info@ironhorsesf.com', 'First_Name': 'None'},
#  {'Email': 'info@ivyroom.com', 'First_Name': 'None'},
#  {'Email': 'info@ivyroom.com', 'First_Name': 'None'},
#  {'Email': 'currents@sausalito.gov', 'First_Name': 'None'},
#  {'Email': 'info@jazzmafia.com', 'First_Name': 'None'},
#  {'Email': 'info@keysjazzbistro.com', 'First_Name': 'None'},
#  {'Email': 'info@kilowattbar.com', 'First_Name': 'None'},
#  {'Email': 'kilowatt@kilowattbar.com', 'First_Name': 'None'},
#  {'Email': 'info@kilowattbar.com', 'First_Name': 'None'},
#  {'Email': 'hello@lastritesbar.com', 'First_Name': 'None'},
#  {'Email': 'lppsf75@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@lighthouse-restaurants.com', 'First_Name': 'None'},
#  {'Email': 'aloha@lycsf.com', 'First_Name': 'None'},
#  {'Email': 'info@nightbirdrestaurant.com', 'First_Name': 'None'},
#  {'Email': 'info@lionsdenbarandlounge.com', 'First_Name': 'None'},
#  {'Email': 'host@localeditionsf.com', 'First_Name': 'None'},
#  {'Email': 'host@localeditionsf.com', 'First_Name': 'None'},
#  {'Email': 'lostcatbar@gmail.com', 'First_Name': 'None'},
#  {'Email': 'lostcatbar@gmail.com', 'First_Name': 'None'},
#  {'Email': 'tonypours@gmail.com', 'First_Name': 'None'},
#  {'Email': 'louies.sf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@lushloungesf.com', 'First_Name': 'None'},
#  {'Email': 'info@madarae.com', 'First_Name': 'None'},
#  {'Email': 'info@michaelkrouse.com', 'First_Name': 'None'},
#  {'Email': 'events@mersea.restaurant', 'First_Name': 'None'},
#  {'Email': 'events@mersea.restaurant', 'First_Name': 'None'},
#  {'Email': 'info@monarchsf.com', 'First_Name': 'None'},
#  {'Email': 'jazz@mrtipplessf.com', 'First_Name': 'None'},
#  {'Email': 'natomacabana@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'booking@neckofthewoodssf.com', 'First_Name': 'None'},
#  {'Email': 'info@nicksrestaurant.net', 'First_Name': 'None'},
#  {'Email': 'nicksrockaway@yahoo.com', 'First_Name': 'None'},
#  {'Email': 'info@novelasf.com', 'First_Name': 'None'},
#  {'Email': 'info@monarchsf.com', 'First_Name': 'None'},
#  {'Email': 'jazz@mrtipplessf.com', 'First_Name': 'None'},
#  {'Email': 'natomacabana@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'booking@neckofthewoodssf.com', 'First_Name': 'None'},
#  {'Email': 'info@nicksrestaurant.net', 'First_Name': 'None'},
#  {'Email': 'nicksrockaway@yahoo.com', 'First_Name': 'None'},
#  {'Email': 'info@novelasf.com', 'First_Name': 'None'},
#  {'Email': 'viceroy@thedooronline.com', 'First_Name': 'None'},
#  {'Email': 'development@viceroyhotelgroup.com', 'First_Name': 'None'},
#  {'Email': 'matt@pixelspread.com', 'First_Name': 'None'},
#  {'Email': 'impallari@gmail.com', 'First_Name': 'None'},
#  {'Email': 'hello@rfuenzalida.com', 'First_Name': 'None'},
#  {'Email': 'info@divinosausalito.com', 'First_Name': 'None'},
#  {'Email': 'hello@outerlandssf.com', 'First_Name': 'None'},
#  {'Email': 'hello@outerlandssf.com', 'First_Name': 'None'},
#  {'Email': 'info@paganidol.com', 'First_Name': 'None'},
#  {'Email': 'info@paganidol.com', 'First_Name': 'None'},
#  {'Email': 'info@persona-sf.com', 'First_Name': 'None'},
#  {'Email': 'events@pier23cafe.com', 'First_Name': 'None'},
#  {'Email': 'mac@pier23cafe.com', 'First_Name': 'None'},
#  {'Email': 'info@pier23cafe.com', 'First_Name': 'None'},
#  {'Email': 'office@pressclubsf.com', 'First_Name': 'None'},
#  {'Email': 'inquiries@radiogatsy.com', 'First_Name': 'None'},
#  {'Email': 'noam@radiogatsby.com', 'First_Name': 'None'},
#  {'Email': 'info@ravenbarsf.com', 'First_Name': 'None'},
#  {'Email': 'email@redwoodroom.com', 'First_Name': 'None'},
#  {'Email': 'cliftsocial@sonesta.com', 'First_Name': 'None'},
#  {'Email': 'info@rickhousebar.com', 'First_Name': 'None'},
#  {'Email': 'info@rickhousebar.com', 'First_Name': 'None'},
#  {'Email': 'info@rickshawstop.com', 'First_Name': 'None'},
#  {'Email': 'info@ryeontheroad.com', 'First_Name': 'None'},
#  {'Email': 'cablecarlounge@yahoo.com', 'First_Name': 'None'},
#  {'Email': 'seafood@scomas.com', 'First_Name': 'None'},
#  {'Email': 'seafood@scomas.com', 'First_Name': 'None'},
#  {'Email': 'tim@scopodivino.com', 'First_Name': 'None'},
#  {'Email': 'info@scopodivino.com', 'First_Name': 'None'},
#  {'Email': 'info@sfjazz.org', 'First_Name': 'None'},
#  {'Email': 'info@smugglerscovesf.com', 'First_Name': 'None'},
#  {'Email': 'losttikiisland@yahoo.com', 'First_Name': 'None'},
#  {'Email': 'soolbar@soolsf.com', 'First_Name': 'None'},
#  {'Email': 'patronservices@sfsymphony.org', 'First_Name': 'None'},
#  {'Email': 'seafood@scomas.com', 'First_Name': 'None'},
#  {'Email': 'tim@scopodivino.com', 'First_Name': 'Tim'},
#  {'Email': 'info@scopodivino.com', 'First_Name': 'None'},
#  {'Email': 'info@sfjazz.org', 'First_Name': 'None'},
#  {'Email': 'info@smugglerscovesf.com', 'First_Name': 'None'},
#  {'Email': 'losttikiisland@yahoo.com', 'First_Name': 'None'},
#  {'Email': 'soolbar@soolsf.com', 'First_Name': 'None'},
#  {'Email': 'patronservices@sfsymphony.org', 'First_Name': 'None'},
#  {'Email': 'mvannorman@sfsymphony.org', 'First_Name': 'None'},
#  {'Email': 'leilani@southsidesf.com', 'First_Name': 'Leilani'},
#  {'Email': 'info@goodbeer.com', 'First_Name': 'None'},
#  {'Email': 'info@swmh.com', 'First_Name': 'None'},
#  {'Email': 'info@swigbar.com', 'First_Name': 'None'},
#  {'Email': 'taintedlovesanfrancisco@gmail.com', 'First_Name': 'None'},
#  {'Email': 'daniel@swanentertainment.com', 'First_Name': 'Daniel'},
#  {'Email': 'tonypours@gmail.com', 'First_Name': 'Tony'},
#  {'Email': 'theshowdownsf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'sfo1hsf.concierge@1hotels.com', 'First_Name': 'None'},
#  {'Email': 'sfo1hsf-terrene@1hotels.com', 'First_Name': 'None'},
#  {'Email': 'sfo1hsf-terrene@1hotels.com', 'First_Name': 'None'},
#  {'Email': 'alembic@booksmith.com', 'First_Name': 'None'},
#  {'Email': 'thealleypianobar@gmail.com', 'First_Name': 'None'},
#  {'Email': 'thealleypianobar@gmail.com', 'First_Name': 'None'},
#  {'Email': 'sam@backroommusic.com', 'First_Name': 'Sam'},
#  {'Email': 'sam@backroommusic.com', 'First_Name': 'Sam'},
#  {'Email': 'leemarieparmelee@hotmail.com', 'First_Name': 'Lee Marie'},
#  {'Email': 'lisa@lisanourse.com', 'First_Name': 'Lisa'},
#  {'Email': 'info@thebeehivesf.com', 'First_Name': 'None'},
#  {'Email': 'thebitterendsf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'blarneystonebar@gmail.com', 'First_Name': 'None'},
#  {'Email': 'thebuenavista@comcast.net', 'First_Name': 'None'},
#  {'Email': 'info@thechapelsf.com', 'First_Name': 'None'},
#  {'Email': 'info@thechapelsf.com', 'First_Name': 'None'},
#  {'Email': 'info@thedevilsacre.com', 'First_Name': 'None'},
#  {'Email': 'info@thedevilsacre.com', 'First_Name': 'None'},
#  {'Email': 'specialevents@livenation.com', 'First_Name': 'None'},
#  {'Email': 'thefillmore@livenation.com', 'First_Name': 'None'},
#  {'Email': 'sf.events@livenation.com', 'First_Name': 'None'},
#  {'Email': 'events@flytrapsf.com', 'First_Name': 'None'},
#  {'Email': 'valen@flytrapsf.com', 'First_Name': 'Valen'},
#  {'Email': 'info@thechapelsf.com', 'First_Name': 'None'},
#  {'Email': 'info@thedevilsacre.com', 'First_Name': 'None'},
#  {'Email': 'info@thedevilsacre.com', 'First_Name': 'None'},
#  {'Email': 'specialevents@livenation.com', 'First_Name': 'None'},
#  {'Email': 'thefillmore@livenation.com', 'First_Name': 'None'},
#  {'Email': 'sf.events@livenation.com', 'First_Name': 'None'},
#  {'Email': 'events@flytrapsf.com', 'First_Name': 'None'},
#  {'Email': 'valen@flytrapsf.com', 'First_Name': 'Valen'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'info@ticketweb.com', 'First_Name': 'None'},
#  {'Email': 'hello@thelaundromatsf.com', 'First_Name': 'None'},
#  {'Email': 'booking@thelostchurch.org', 'First_Name': 'None'},
#  {'Email': 'ticketing@thelostchurch.org', 'First_Name': 'None'},
#  {'Email': 'hq@thelostchurch.org', 'First_Name': 'None'},
#  {'Email': 'info@thepagebar.com', 'First_Name': 'None'},
#  {'Email': 'info@patiosf.com', 'First_Name': 'None'},
#  {'Email': 'info@thepatiosf.com', 'First_Name': 'None'},
#  {'Email': 'damien@thepawnshopsf.com', 'First_Name': 'Damien'},
#  {'Email': 'damien@thepawnshopsf.com', 'First_Name': 'Damien'},
#  {'Email': 'info@redpoppyarthouse.org', 'First_Name': 'None'},
#  {'Email': 'volunteer@redpoppyarthouse.org', 'First_Name': 'None'},
#  {'Email': 'booking@riptidesf.com', 'First_Name': 'None'},
#  {'Email': 'riptidesf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'will@theroyalesf.com', 'First_Name': 'Will'},
#  {'Email': 'westontoyou@gmail.com', 'First_Name': 'None'},
#  {'Email': 'westontoyou@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@therumpusroomsf.com', 'First_Name': 'None'},
#  {'Email': 'info@theseastarsf.com', 'First_Name': 'None'},
#  {'Email': 'info@sherwoodsf.com', 'First_Name': 'None'},
#  {'Email': 'info@sherwoodsf.com', 'First_Name': 'None'},
#  {'Email': 'soundroomoakland@gmail.com', 'First_Name': 'None'},
#  {'Email': 'soundroomoakland@gmail.com', 'First_Name': 'None'},
#  {'Email': 'boxoffice@thespeakeasysf.com', 'First_Name': 'None'},
#  {'Email': 'boxoffice@thespeakeasysf.com', 'First_Name': 'None'},
#  {'Email': 'swerney@thetreasurysf.com', 'First_Name': 'None'},
#  {'Email': 'lisa@lisanourse.com', 'First_Name': 'Lisa'},
#  {'Email': 'hil@thetreasurysf.com', 'First_Name': 'Hil'},
#  {'Email': 'arnold@thetreasurysf.com', 'First_Name': 'Arnold'},
#  {'Email': 'contact@thetreasurysf.com', 'First_Name': 'None'},
#  {'Email': 'alexeyberlind@gmail.com', 'First_Name': 'None'},
#  {'Email': 'boxoffice@thespeakeasysf.com', 'First_Name': 'None'},
#  {'Email': 'swerney@thetreasurysf.com', 'First_Name': 'None'},
#  {'Email': 'lisa@lisanourse.com', 'First_Name': 'Lisa'},
#  {'Email': 'hil@thetreasurysf.com', 'First_Name': 'Hil'},
#  {'Email': 'arnold@thetreasurysf.com', 'First_Name': 'Arnold'},
#  {'Email': 'contact@thetreasurysf.com', 'First_Name': 'None'},
#  {'Email': 'alexeyberlind@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@thevalenciaroom.com', 'First_Name': 'None'},
#  {'Email': 'proteam@mopro.com', 'First_Name': 'None'},
#  {'Email': 'noreply@mopro.com', 'First_Name': 'None'},
#  {'Email': 'declan@valleytavern.us', 'First_Name': 'Declan'},
#  {'Email': 'viewlounge@marriott.com', 'First_Name': 'None'},
#  {'Email': 'booking@theeparkside.com', 'First_Name': 'None'},
#  {'Email': 'theeparkside@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@thirdrailbarsf.com', 'First_Name': 'None'},
#  {'Email': 'thrills@thrillersocialclub.com', 'First_Name': 'None'},
#  {'Email': 'tongaroom@fairmont.com', 'First_Name': 'None'},
#  {'Email': 'sanfrancisco@fairmont.com', 'First_Name': 'None'},
#  {'Email': 'topesf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@tropisueno.com', 'First_Name': 'None'},
#  {'Email': 'tupelosf@gmail.com', 'First_Name': 'None'},
#  {'Email': 'frank@funnyfrank.com', 'First_Name': 'Frank'},
#  {'Email': 'info@uccellolounge.com', 'First_Name': 'None'},
#  {'Email': 'vicswinehouse@gmail.com', 'First_Name': 'None'},
#  {'Email': 'info@violets-sf.com', 'First_Name': 'None'},
#  {'Email': 'host@bourbonandbranch.com', 'First_Name': 'None'},
#  {'Email': 'lindsay@yielddogpatch.com', 'First_Name': 'Lindsay'}]
